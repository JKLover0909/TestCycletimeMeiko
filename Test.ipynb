# %%
# !python AIDetect.py --image_path /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg --confidence 0.5
# Out:
# ✅ Loaded Thuadong as OBB model
# ✅ Loaded KhuyetMach as OBB model
# ✅ Loaded NganMach as OBB model
# ✅ Loaded VetLom as OBB model
# ✅ Loaded Xuoc as OBB model
# Loading /home/jkl0909/TestCycletimeMeiko/Modelx/khuyetmach.engine for TensorRT inference...
# Loading /home/jkl0909/TestCycletimeMeiko/Modelx/thuadong.engine for TensorRT inference...
# Loading /home/jkl0909/TestCycletimeMeiko/Modelx/nganmach.engine for TensorRT inference...
# Loading /home/jkl0909/TestCycletimeMeiko/Modelx/vetlom.engine for TensorRT inference...
# Loading /home/jkl0909/TestCycletimeMeiko/Modelx/xuoc.engine for TensorRT inference...
# [06/18/2025-18:48:00] [TRT] [I] The logger passed into createInferRuntime differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
# ...

# %%
# !python Segment.py --image_path /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg --class_name ThuaDong --coordinates "217,241,292,319" --theta -89.6
# Out:
# 🎭 SAM Segmentation Pipeline
# ...
# 📂 Image: /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg
# 🎯 Class: ThuaDong
# 📐 Coordinates: 217,241,292,319
# 🔄 Theta: -89.60°
# 🤖 Model: /home/jkl0909/TestCycletimeMeiko/sam2.1_s.pt
#
# 📸 Loading image...
# ✅ Image loaded: (600, 600, 3)
# 🔄 Loading SAM model...
# 📁 Model path: /home/jkl0909/TestCycletimeMeiko/sam2.1_s.pt
# ✅ SAM model loaded with Ultralytics!
# 🎭 Running segmentation...
# 🎯 Segmenting bbox: [217, 241, 292, 319]
# 🎯 Image shape: (600, 600, 3)
# 🎯 Validated bbox: [217, 241, 292, 319]
#
# 0: 1024x1024 1 0, 444.3ms
# Speed: 18.9ms preprocess, 444.3ms inference, 28.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ✅ Segmentation successful
# 📏 Analyzing contours...
# 🔍 Analyzing mask: shape=(1, 600, 600), dtype=uint8
# 🔍 Mask stats: min=0, max=1, unique=[0 1]
# 🔍 Processed mask: shape=(600, 600), dtype=uint8
# 🔍 Processed stats: min=0, max=1
# 🔍 Largest contour: (92, 1, 2)
# ✅ Contour analysis successful:
# ...

# %%
# !python Calculator.py --segmentation_data /home/jkl0909/TestCycletimeMeiko/sam_segmentation_results/segmentation_data_ThuaDong_20250618_183310.json --image_path /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg
# Out:
# 🧮 Rotated BBox Calculator v6.0
# ...
# 📂 Segmentation Data: /home/jkl0909/TestCycletimeMeiko/sam_segmentation_results/segmentation_data_ThuaDong_20250618_183310.json
# 📸 Image: /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg
# 🎯 Class: ThuaDong
# 🔄 Theta: -89.60°
# 📊 Calculating original bounding box...
# 📊 Calculating rotated bounding box...
# 📊 CALCULATION RESULTS:
#    Original BBox: 66.0 x 58.0 pixels (area: 3828.0)
#    Rotated BBox: 57.9 x 66.1 pixels (area: 3828.9)
#    Rotation: -89.60°
#    Contour Area: 2895.5 pixels
# 🎨 Creating rotated image visualization...
# 🎨 Creating rotated visualization...
#    Image: testthuadong.jpg
#    Rotation: -89.60°
#    Output: /home/jkl0909/TestCycletimeMeiko/calculation_results/rotated_analysis_ThuaDong_20250618_191806.png
#    Original image size: 600 x 600
#    Rotated image size: 604 x 604
# ...

# %%
# !python Infer.py --image_path /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg --confidence 0.5
# Out:
# 🚀 Complete Inference Pipeline v3.0
# ...
# 📂 Image: /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg
# 🎯 Confidence: 0.5
# 🕒 Started: 2025-06-18 18:54:54
#
# 🤖 Step 1: Running AI Detection...
#    Image: /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg
#    Confidence: 0.5
# 🔍 Command: python AIDetect.py --image_path /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg --confidence 0.5
# ✅ Successfully parsed: ThuaDong at 217,241,292,319
# ✅ Detection successful: 1 objects found
#    1. ThuaDong (conf: 0.934)
#
# 📊 Processing: ThuaDong (confidence: 0.934)
# 🎭 Step 2: Running SAM Segmentation...
#    Class: ThuaDong
#    Coordinates: 217,241,292,319
#    Angle: -89.60°
# 🔍 Command: python Segment.py --image_path /home/jkl0909/TestCycletimeMeiko/Data/thuadong/testthuadong.jpg --class_name ThuaDong --coordinates 217,241,292,319 --theta -89.6
# ✅ Segmentation successful
#    Area: 2895.5 pixels
#    Points: 92
# ...
